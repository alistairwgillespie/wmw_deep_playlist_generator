# %% [markdown]
# # Wilson's Morning Wake Up, Pipeline
# Simply creates a playlist object and generates a new Wilson's FM playlist.

# %%
import os
import pandas as pd
from playlist import Playlist

# %%
# Data Directory 
data_dir = 'data'

# %%
# Read in WMW tracks to date for recommendations
track_data = pd.read_csv(os.path.join(data_dir, "wmw_tracks.csv"))

track_data.head()
# Out:
#    volume  position                                   track_name  \
# 0      38         1                             Finding It There
# 1      38         2                                  Light Forms
# 2      38         3                                       C-Side
# 3      38         4               Didn't I (Dave Allison Rework)
# 4      38         5  Woman Of The Ghetto - Akshin Alizadeh Remix
#
#     artist_name  danceability   energy  key  loudness  mode  speechiness  ...  \
# 0      Goldmund         0.187  0.00257    1   -37.134     1       0.0427  ...
# 1         Rohne         0.671  0.54500   10   -12.848     0       0.0393  ...
# 2    Khruangbin         0.688  0.77900   11   -10.129     0       0.0579  ...
# 3       Darondo         0.539  0.70500    0    -6.729     1       0.0527  ...
# 4  Marlena Shaw         0.707  0.57300    7    -8.403     0       0.0276  ...
#
#    liveness  valence    tempo            type                      id  \
# 0    0.0915   0.0374  123.707  audio_features  6CnPCuUcM3A5PMP4gUy0vw
# 1    0.1180   0.2840  133.036  audio_features  6MkUPsz5hYeneo0a9H0VT8
# 2    0.3490   0.9380   94.073  audio_features  6GvAM8oyVApQHGMgpBt8yl
# 3    0.1330   0.6850  186.033  audio_features  1owjOeZt1BdYWW6T8fIAEe
# 4    0.0858   0.1890  100.006  audio_features  2h8cQH7zhUWrynZi2MKhhC
#
#                                     uri  \
# 0  spotify:track:6CnPCuUcM3A5PMP4gUy0vw
# 1  spotify:track:6MkUPsz5hYeneo0a9H0VT8
# 2  spotify:track:6GvAM8oyVApQHGMgpBt8yl
# 3  spotify:track:1owjOeZt1BdYWW6T8fIAEe
# 4  spotify:track:2h8cQH7zhUWrynZi2MKhhC
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6CnPCuUcM3A5...
# 1  https://api.spotify.com/v1/tracks/6MkUPsz5hYen...
# 2  https://api.spotify.com/v1/tracks/6GvAM8oyVApQ...
# 3  https://api.spotify.com/v1/tracks/1owjOeZt1BdY...
# 4  https://api.spotify.com/v1/tracks/2h8cQH7zhUWr...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6CnP...      220120
# 1  https://api.spotify.com/v1/audio-analysis/6MkU...      265870
# 2  https://api.spotify.com/v1/audio-analysis/6GvA...      283407
# 3  https://api.spotify.com/v1/audio-analysis/1owj...      328000
# 4  https://api.spotify.com/v1/audio-analysis/2h8c...      302467
#
#   time_signature
# 0              5
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 22 columns]

# %%
# %%time 

# Generate playlist
pl = Playlist(track_data)
# Out:
# Intro track: Til Mathilde - Tine Mydland
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Track #2 - Generating candidates
# Recommendations (200, 20)
# Curr mode (27, 20)
# Change mode (12, 20)
# CANDIDATES: (39, 20)
# Selected: Full Circle - Bonobo Remix - George FitzGerald, Boxed In, Bonobo
# --------------------
# Track #3 - Generating candidates
# Recommendations (200, 20)
# Curr mode (15, 20)
# Change mode (14, 20)
# CANDIDATES: (29, 20)
# Selected: Kings - Frameworks
# --------------------
# Track #4 - Generating candidates
# Recommendations (200, 20)
# Curr mode (20, 20)
# Change mode (11, 20)
# CANDIDATES: (31, 20)
# Selected: Found Your Love - Bosq, Kuyen
# --------------------
# Track #5 - Generating candidates
# Recommendations (200, 20)
# Curr mode (25, 20)
# Change mode (3, 20)
# CANDIDATES: (28, 20)
# Selected: Further - ATTLAS
# --------------------
# Track #6 - Generating candidates
# Recommendations (200, 20)
# Curr mode (18, 20)
# Change mode (10, 20)
# CANDIDATES: (28, 20)
# Selected: Nova - Yotto
# --------------------
# Track #7 - Generating candidates
# Recommendations (200, 20)
# Curr mode (14, 20)
# Change mode (6, 20)
# CANDIDATES: (20, 20)
# Selected: Lies - Trifonic
# --------------------
# Track #8 - Generating candidates
# Recommendations (200, 20)
# Curr mode (28, 20)
# Change mode (1, 20)
# CANDIDATES: (29, 20)
# Selected: Hear Me Out - Yotto, SØNIN, Laudic
# --------------------
# Track #9 - Generating candidates
# Recommendations (200, 20)
# Curr mode (28, 20)
# Change mode (6, 20)
# CANDIDATES: (34, 20)
# Selected: Elephants - Original Mix - PHCK
# --------------------
# Track #10 - Generating candidates
# Recommendations (200, 20)
# Curr mode (22, 20)
# Change mode (9, 20)
# CANDIDATES: (31, 20)
# Selected: Silent Drop - Original Mix - Dosem
# --------------------
# Track #11 - Generating candidates
# Recommendations (200, 20)
# Curr mode (26, 20)
# Change mode (16, 20)
# CANDIDATES: (42, 20)
# Selected: Sleep Sound - Jamie xx
# --------------------
# Track #12 - Generating candidates
# Song not searchable
# Recommendations (180, 20)
# Curr mode (25, 20)
# Change mode (9, 20)
# CANDIDATES: (34, 20)
# Selected: Don't Change - Last Island
# --------------------
# Track #13 - Generating candidates
# Recommendations (200, 20)
# Curr mode (33, 20)
# Change mode (13, 20)
# CANDIDATES: (46, 20)
# Selected: King Bromeliad - Floating Points
# --------------------
# Track #14 - Generating candidates
# Recommendations (200, 20)
# Curr mode (27, 20)
# Change mode (10, 20)
# CANDIDATES: (37, 20)
# Selected: Parfume - Eli & Fur
# --------------------
# Track #15 - Generating candidates
# Recommendations (160, 20)
# Curr mode (22, 20)
# Change mode (5, 20)
# CANDIDATES: (27, 20)
# Selected: Waves - Max Cooper
# --------------------
#
# Wall time: 12min 2s

# %%
# Post playlist to Spotify
pl.post_playlist()
# Out:
# Posting latest Wilson's FM.
