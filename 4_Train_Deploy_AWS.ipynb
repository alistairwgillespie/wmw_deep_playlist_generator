# %% [markdown]
# # Wilson's Morning Wake Up Playlist Generator, Modeling and Learning
#
# ## AWS SageMaker
#
# The following steps will be executed:
#
# * Upload your data to S3.
# * Define a benchmark and candidate models and training scripts
# * Train models and deploy.
# * Evaluate deployed estimator.

# %%
# Defaults
import os
import sys

import pandas as pd
import numpy as np

from scipy.spatial.distance import cdist
from tqdm.notebook import tqdm
from sklearn.externals import joblib

import torch
import torch.optim as optim

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from mpl_toolkits import mplot3d

import numpy as np
import matplotlib.pyplot as plt

# %%
import boto3
import sagemaker

# %%
# session and role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# create an S3 bucket
bucket = sagemaker_session.default_bucket()

# %%
# !ls -la data
# Out:
# total 648
# drwxrwxr-x  3 ec2-user ec2-user   4096 Apr 15 05:22 .
# drwxrwxr-x 10 ec2-user ec2-user   4096 Apr 15 10:36 ..
# drwxrwxr-x  2 ec2-user ec2-user   4096 Apr 15 05:22 .ipynb_checkpoints
# -rw-rw-r--  1 ec2-user ec2-user 159916 Apr 15 00:51 tensor_train.csv
# -rw-rw-r--  1 ec2-user ec2-user  28467 Mar  4 23:01 test.csv
# -rw-rw-r--  1 ec2-user ec2-user 186224 Apr 15 00:51 train.csv
# -rw-rw-r--  1 ec2-user ec2-user 101182 Apr 15 00:51 wmw.csv
# -rw-rw-r--  1 ec2-user ec2-user 166967 Apr 15 00:51 wmw_tracks.csv

# %% [markdown]
# ## Upload your training data to S3

# %%
# should be the name of directory you created to save your features data
data_dir = 'data'

# %%
# set prefix, a descriptive name for a directory  
prefix = 'sagemaker/wmw_deep_playlist_generator'

# upload all data to S3
input_data = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)

# %%
# confirm that data is in S3 bucket
empty_check = []
for obj in boto3.resource('s3').Bucket(bucket).objects.all():
    empty_check.append(obj.key)
    print(obj.key)

assert len(empty_check) !=0, 'S3 bucket is empty.'
print('Test passed!')
# Out:
# pytorch-training-2020-04-15-06-10-59-220/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-06-24-29-105/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-06-50-28-851/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-06-56-56-010/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-07-02-05-077/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-07-11-18-087/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-09-14-29-568/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-09-19-54-968/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-09-20-43-042/model.tar.gz
# pytorch-training-2020-04-15-09-20-43-042/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-09-35-00-735/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-09-43-29-339/model.tar.gz
# pytorch-training-2020-04-15-09-43-29-339/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-09-58-47-352/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-10-09-00-811/model.tar.gz
# pytorch-training-2020-04-15-10-09-00-811/source/sourcedir.tar.gz
# pytorch-training-2020-04-15-10-23-18-830/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-02-28-12-037/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-02-33-00-824/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-02-44-07-338/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-02-50-38-799/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-02-55-06-846/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-03-20-37-741/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-03-24-38-828/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-03-31-46-455/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-03-38-27-561/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-03-05-03-44-02-776/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-01-36-56-562/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-03-08-01-389/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-03-16-55-792/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-04-50-11-752/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-04-56-47-934/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-13-09-836/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-22-51-290/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-31-00-406/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-35-38-059/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-40-42-569/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-45-45-535/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-05-55-34-372/source/sourcedir.tar.gz
# sagemaker-pytorch-2020-04-15-06-00-33-045/source/sourcedir.tar.gz
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/collections/000000000/worker_0_collections.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000000000/000000000000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000000500/000000000500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000001000/000000001000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000001500/000000001500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000002000/000000002000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000002500/000000002500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000003000/000000003000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000003500/000000003500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000004000/000000004000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000004500/000000004500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000005000/000000005000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000005500/000000005500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000006000/000000006000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000006500/000000006500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000007000/000000007000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000007500/000000007500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000008000/000000008000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000008500/000000008500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000009000/000000009000_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000000009500/000000009500_worker_0.tfevents
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-06-10-59-220/debug-output/events/000
_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000079/000000079500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000080/000000080000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000080/000000080500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000081/000000081000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000081/000000081500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000082/000000082000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000082/000000082500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000083/000000083000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000083/000000083500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000084/000000084000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000084/000000084500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000085/000000085000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000085/000000085500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000086/000000086000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000086/000000086500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000087/000000087000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000087/000000087500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000088/000000088000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000088/000000088500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000089/000000089000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000089/000000089500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000090/000000090000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000090/000000090500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000091/000000091000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000091/000000091500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000092/000000092000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000092/000000092500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000093/000000093000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000093/000000093500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000094/000000094000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000094/000000094500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000095/000000095000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000095/000000095500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000096/000000096000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000096/000000096500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000097/000000097000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000097/000000097500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000098/000000098000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000098/000000098500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000099/000000099000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000099/000000099500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000100/000000100000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000100/000000100500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000101/000000101000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000101/000000101500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000102/000000102000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000102/000000102500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000103/000000103000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000103/000000103500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000104/000000104000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000104/000000104500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000105/000000105000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000105/000000105500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000106/000000106000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000106/000000106500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000107/000000107000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000107/000000107500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000108/000000108000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000108/000000108500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000109/000000109000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000109/000000109500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000110/000000110000_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/index/000000110/000000110500_worker_0.json
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/debug-output/training_job_end.ts
# sagemaker/wmw_deep_playlist_generator/pytorch-training-2020-04-15-10-09-00-811/output/model.tar.gz
# sagemaker/wmw_deep_playlist_generator/tensor_train.csv
# sagemaker/wmw_deep_playlist_generator/test.csv
# sagemaker/wmw_deep_playlist_generator/train.csv
# sagemaker/wmw_deep_playlist_generator/wmw.csv
# sagemaker/wmw_deep_playlist_generator/wmw_tracks.csv
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-02-28-12-037/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-02-33-00-824/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-02-44-07-338/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-02-50-38-799/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-02-55-06-846/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-20-37-741/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-24-38-828/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-31-46-455/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-38-27-561/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-38-27-561/output/model.tar.gz
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-44-02-776/debug-output/training_job_end.ts
# sagemaker/wmw_estimator/sagemaker-pytorch-2020-03-05-03-44-02-776/output/model.tar.gz
# sagemaker/wmw_estimator/tensor_train_df.csv
# sagemaker/wmw_estimator/test.csv
# sagemaker/wmw_estimator/train.csv
# sagemaker/wmw_estimator/wmw.csv
# sagemaker/wmw_estimator/wmw_tracks.csv
# Test passed!

# %% [markdown]
# ---
#
# # Modeling
#
# It's time to define and train the models!
#
# ---
#
# ## Complete a training script
#
# To implement a custom estimator, I need to complete a `train.py` script.
#
# A typical training script:
# * Loads training data from a specified directory
# * Parses any training & model hyperparameters (ex. nodes in a neural network, training epochs, etc.)
# * Instantiates a model of your design, with any specified hyperparams
# * Trains that model
# * Finally, saves the model so that it can be hosted/deployed, later
#
# ### Defining and training a model
#
# To complete a `train.py` file, you will:
# 1. Import any extra libraries you need
# 2. Define any additional model training hyperparameters using `parser.add_argument`
# 2. Define a model in the `if __name__ == '__main__':` section
# 3. Train the model in that same section

# %%
# Directory of train.py
# !pygmentize model/LSTM_Train.py
# Out:
# Error: cannot read infile: [Errno 2] No such file or directory: 'model/LSTM_Train.py'

# %% [markdown]
# ---
# # Create an Estimator
#
# When a custom model is constructed in SageMaker, an entry point must be specified. This is the Python file which will be executed when the model is trained; the `train.py` function you specified above. To run a custom training script in SageMaker, construct an estimator, and fill in the appropriate constructor arguments:
#
# * **entry_point**: The path to the Python script SageMaker runs for training and prediction.
# * **source_dir**: The path to the training script directory `source_sklearn` OR `source_pytorch`.
# * **entry_point**: The path to the Python script SageMaker runs for training and prediction.
# * **source_dir**: The path to the training script directory `train_sklearn` OR `train_pytorch`.
# * **entry_point**: The path to the Python script SageMaker runs for training.
# * **source_dir**: The path to the training script directory `train_sklearn` OR `train_pytorch`.
# * **role**: Role ARN, which was specified, above.
# * **train_instance_count**: The number of training instances (should be left at 1).
# * **train_instance_type**: The type of SageMaker instance for training. Note: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * **sagemaker_session**: The session used to train on Sagemaker.
# * **hyperparameters** (optional): A dictionary `{'name':value, ..}` passed to the train function as hyperparameters.
#
# Note: For a PyTorch model, there is another optional argument **framework_version**, which you can set to the latest version of PyTorch, `1.0`.
#
# ## Define PyTorch estimators

# %% [markdown]
# ### Test run of benchmark (RNN) and candidate model (LSTM) and train components
# Here I will see if the configurations I have set work accordingly with no errors. Once it runs smoothly, I will instantiate an estimator using the Sagemaker API.

# %%
from model import PlaylistDataset

dataset =  PlaylistDataset.PlaylistDataset(data_dir, "tensor_train.csv")

dataloader = DataLoader(dataset, batch_size=12, shuffle=False)

# %%
# Training function for LSTM
def train_lstm(model, train_loader, epochs, criterion, optimizer, device):
    """
    This is the training method that is called by the PyTorch training script of the LSTM model. The parameters
    passed are as follows:
    model        - The PyTorch model that we wish to train.
    train_loader - The PyTorch DataLoader that should be used during training.
    epochs       - The total number of epochs to train for.
    criterion    - The loss function used for training. 
    optimizer    - The optimizer to use during training.
    device       - Where the model and data should be loaded (gpu or cpu).
    """
    
    model.train() # Make sure that the model is in training mode.
    
    # training loop is provided
    for epoch in range(1, epochs + 1):
        
        for i, batch in enumerate(train_loader):

            optimizer.zero_grad()

            cum_loss = 0
            
            hidden_cell = model.init_hidden()
            
            for i, track in enumerate(batch):
                
                track_x = track[0]
                track_y = track[-1]
                
                output, hidden_cell = model(track_x.unsqueeze(0), hidden_cell)
                
                loss = criterion(output.squeeze(0), track_y)
                loss.backward(retain_graph=True)
                optimizer.step()
                cum_loss += loss.data.item()

            total_loss = cum_loss / len(batch[0])
            
        if epoch % 50 == 0:
            print('Epoch: {}/{}.............'.format(epoch, epochs), end=' ')
            print("Loss: {:.4f}".format(total_loss))

# %%
from model.LstmEstimator import LstmEstimator

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
lstm_model = LstmEstimator(9, 30, 1, 9)
optimizer = optim.Adam(lstm_model.parameters(), lr=0.001)
loss_fn = torch.nn.L1Loss()

train_lstm(lstm_model, dataloader, 50, loss_fn, optimizer, device)
# Out:
# Epoch: 50/50............. Loss: 0.1057

# %%
# Save LSTM
# torch.save(lstm_model.state_dict(), 'artefacts/lstm_model.pth')

# %%
# Training function for RNN
def train_rnn(model, dataloader, epochs, criterion, optimizer, device):
    
    model.train() # Make sure that the model is in training mode.
    
    for epoch in range(1, epochs + 1):

        for i, batch in enumerate(dataloader):
            
            cum_loss = 0
            
            hidden = model.initHidden()
            
            optimizer.zero_grad()
        
            for i, track in enumerate(batch):

                track_x = track[0]
                track_y = track[-1]
                
                output, hidden = model(track_x.unsqueeze(0), hidden)
            
                loss = criterion(output.squeeze(0), track_y)
                loss.backward()
                optimizer.step()
                cum_loss += loss.data.item()
                
            total_loss = cum_loss / len(batch[0])

        if epoch % 50 == 0:
            print('Epoch: {}/{}.............'.format(epoch, epochs), end=' ')
            print("Loss: {:.4f}".format(total_loss))

# %%
from model.RnnEstimator import RnnEstimator

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
rnn_model = RnnEstimator(9, 30, 9)
optimizer = optim.Adam(rnn_model.parameters(), lr=0.001)
loss_fn = torch.nn.L1Loss()

train_rnn(rnn_model, dataloader, 50, loss_fn, optimizer, device)
# Out:
# Epoch: 50/50............. Loss: 0.1746

# %%
# Save RNN
# torch.save(rnn_model.state_dict(), 'artefacts/rnn_model.pth')

# %% [markdown]
# ### Build and Train the PyTorch Model with Hyperparameter Tuning

# %%
# Estimator code
from sagemaker.pytorch import PyTorch

output_path = 's3://{}/{}'.format(bucket, prefix)

lstm_estimator = PyTorch(entry_point="LstmTrain.py",
                    source_dir="model",
                    role=role,
                    framework_version='1.4.0',
                    train_instance_count=1,
                    output_path = output_path,
                    train_instance_type='ml.m4.xlarge',
                    hyperparameters={
                        'input_features': 9,
                        'hidden_dim': 30,
                        'hidden_layers': 1,
                        'output_dim': 9,
                        'epochs': 1500
                    })

# %%
# Fit estimator
lstm_estimator.fit({'train': input_data})
# Out:
# 2020-04-15 10:09:01 Starting - Starting the training job...
# 2020-04-15 10:09:03 Starting - Launching requested ML instances...
# 2020-04-15 10:10:01 Starting - Preparing the instances for training......
# 2020-04-15 10:10:57 Downloading - Downloading input data......
# 2020-04-15 10:11:55 Training - Downloading the training image...
# 2020-04-15 10:12:15 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-04-15 10:12:16,138 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-04-15 10:12:16,144 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:12:16,168 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-04-15 10:12:19,187 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-04-15 10:12:19,528 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2020-04-15 10:12:19,528 sagemaker-containers INFO     Generating setup.cfg
# 2020-04-15 10:12:19,528 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-04-15 10:12:19,529 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install .
# Processing /tmp/tmpa0fghxcw/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=24546 sha256=5a56c4506912ddf71d12368254919579fbe9950fa276665ad79d1e5b0bbdff66
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lq8pyubj/wheels/2f/8d/77/32eab65e5f294122fa3039ed9609a2e90c3f3183d82f27cf9e
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2020-04-15 10:12:21,910 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:12:21,926 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:12:21,942 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:12:21,956 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "hidden_dim": 30,
#         "input_features": 9,
#         "epochs": 1500,
#         "output_dim": 9,
#         "hidden_layers": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2020-04-15-10-09-00-811",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-southeast-2-999752527953/pytorch-training-2020-04-15-10-09-00-811/source/sourcedir.tar.gz",
#     "module_name": "LstmTrain",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "LstmTrain.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1500,"hidden_dim":30,"hidden_layers":1,"input_features":9,"output_dim":9}
# SM_USER_ENTRY_POINT=LstmTrain.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=LstmTrain
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-southeast-2-999752527953/pytorch-training-2020-04-15-10-09-00-811/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1500,"hidden_dim":30,"hidden_layers":1,"input_features":9,"output_dim":9},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2020-04-15-10-09-00-811","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-southeast-2-999752527953/pytorch-training-2020-04-15-10-09-00-811/source/sourcedir.tar.gz","module_name":"LstmTrain","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"LstmTrain.py"}
# SM_USER_ARGS=["--epochs","1500","--hidden_dim","30","--hidden_layers","1","--input_features","9","--output_dim","9"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_HIDDEN_DIM=30
# SM_HP_INPUT_FEATURES=9
# SM_HP_EPOCHS=1500
# SM_HP_OUTPUT_DIM=9
# SM_HP_HIDDEN_LAYERS=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python LstmTrain.py --epochs 1500 --hidden_dim 30 --hidden_layers 1 --input_features 9 --output_dim 9
#
#
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (0.25.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.6/site-packages (from pandas) (1.16.4)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Using device cpu.
# Get train data loader.
# [2020-04-15 10:12:25.680 algo-1:43 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-04-15 10:12:25.681 algo-1:43 INFO hook.py:170] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-04-15 10:12:25.681 algo-1:43 INFO hook.py:215] Saving to /opt/ml/output/tensors
# [2020-04-15 10:12:25.681 algo-1:43 INFO hook.py:351] Monitoring the collections: losses
# Epoch: 50/1500............. Loss: 0.1054
# Epoch: 100/1500............. Loss: 0.0399
# Epoch: 150/1500............. Loss: 0.0245
# Epoch: 200/1500............. Loss: 0.0061
# Epoch: 250/1500............. Loss: 0.0081
# Epoch: 300/1500............. Loss: 0.0071
# Epoch: 350/1500............. Loss: 0.0086
# Epoch: 400/1500............. Loss: 0.0052
# Epoch: 450/1500............. Loss: 0.0043
# Epoch: 500/1500............. Loss: 0.0045
# Epoch: 550/1500............. Loss: 0.0046
# Epoch: 600/1500............. Loss: 0.0078
# Epoch: 650/1500............. Loss: 0.0046
# Epoch: 700/1500............. Loss: 0.0061
# Epoch: 750/1500............. Loss: 0.0071
# Epoch: 800/1500............. Loss: 0.0100
# Epoch: 850/1500............. Loss: 0.0075
# Epoch: 900/1500............. Loss: 0.0093
# Epoch: 950/1500............. Loss: 0.0056
# Epoch: 1000/1500............. Loss: 0.0069
# Epoch: 1050/1500............. Loss: 0.0073
# Epoch: 1100/1500............. Loss: 0.0071
# Epoch: 1150/1500............. Loss: 0.0075
# Epoch: 1200/1500............. Loss: 0.0067
# Epoch: 1250/1500............. Loss: 0.0063
# Epoch: 1300/1500............. Loss: 0.0056
# Epoch: 1350/1500............. Loss: 0.0067
# Epoch: 1400/1500............. Loss: 0.0059
# Epoch: 1450/1500............. Loss: 0.0064
# Epoch: 1500/1500............. Loss: 0.0062
# [2020-04-15 10:16:05.727 algo-1:43 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-04-15 10:16:05,905 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-04-15 10:16:15 Uploading - Uploading generated training model
# 2020-04-15 10:16:15 Completed - Training job completed
# Training seconds: 318
# Billable seconds: 318

# %%
# %%time

# deploy your model to create a predictor
# lstm_playlist_predictor = lstm_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# -------------!CPU times: user 356 ms, sys: 20.3 ms, total: 377 ms
# Wall time: 6min 32s

# %%
rnn_estimator = PyTorch(entry_point="RnnTrain.py",
                    source_dir="model",
                    role=role,
                    framework_version='1.4.0',
                    train_instance_count=1,
                    output_path = output_path,
                    train_instance_type='ml.m4.xlarge',
                    hyperparameters={
                        'input_features': 9,
                        'hidden_dim': 30,
                        'output_dim': 9,
                        'epochs': 1500
                    })

# %%
# Fit estimator
rnn_estimator.fit({'train': input_data})
# Out:
# 2020-04-15 10:37:39 Starting - Starting the training job...
# 2020-04-15 10:37:41 Starting - Launching requested ML instances...
# 2020-04-15 10:38:39 Starting - Preparing the instances for training......
# 2020-04-15 10:39:18 Downloading - Downloading input data......
# 2020-04-15 10:40:32 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-04-15 10:40:33,190 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-04-15 10:40:33,194 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:40:33,207 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-04-15 10:40:34,622 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-04-15 10:40:34,920 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2020-04-15 10:40:34,920 sagemaker-containers INFO     Generating setup.cfg
# 2020-04-15 10:40:34,921 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-04-15 10:40:34,921 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install .
# Processing /tmp/tmp2bgvfv2a/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=24548 sha256=c0817bfa82101e507cf95edd2240281fa5eb75e30fc69106f9866c1f62d8b12b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cmpzrdcq/wheels/92/ce/c9/366872bbbdf724ee25b44a4cd47bd9603e5375cc5f1a197e12
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2020-04-15 10:40:37,416 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:40:37,432 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:40:37,448 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-04-15 10:40:37,463 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "hidden_dim": 30,
#         "input_features": 9,
#         "epochs": 1500,
#         "output_dim": 9
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2020-04-15-10-37-39-247",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-southeast-2-999752527953/pytorch-training-2020-04-15-10-37-39-247/source/sourcedir.tar.gz",
#     "module_name": "RnnTrain",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "RnnTrain.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1500,"hidden_dim":30,"input_features":9,"output_dim":9}
# SM_USER_ENTRY_POINT=RnnTrain.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=RnnTrain
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-southeast-2-999752527953/pytorch-training-2020-04-15-10-37-39-247/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1500,"hidden_dim":30,"input_features":9,"output_dim":9},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2020-04-15-10-37-39-247","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-southeast-2-999752527953/pytorch-training-2020-04-15-10-37-39-247/source/sourcedir.tar.gz","module_name":"RnnTrain","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"RnnTrain.py"}
# SM_USER_ARGS=["--epochs","1500","--hidden_dim","30","--input_features","9","--output_dim","9"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_HIDDEN_DIM=30
# SM_HP_INPUT_FEATURES=9
# SM_HP_EPOCHS=1500
# SM_HP_OUTPUT_DIM=9
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python RnnTrain.py --epochs 1500 --hidden_dim 30 --input_features 9 --output_dim 9
#
#
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.6/site-packages (from pandas) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Using device cpu.
# Get train data loader.
# [2020-04-15 10:40:41.200 algo-1:43 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-04-15 10:40:41.201 algo-1:43 INFO hook.py:170] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-04-15 10:40:41.201 algo-1:43 INFO hook.py:215] Saving to /opt/ml/output/tensors
# [2020-04-15 10:40:41.202 algo-1:43 INFO hook.py:351] Monitoring the collections: losses
# Epoch: 50/1500............. Loss: 0.1863
# Epoch: 100/1500............. Loss: 0.1826
# Epoch: 150/1500............. Loss: 0.1766
# Epoch: 200/1500............. Loss: 0.1769
# Epoch: 250/1500............. Loss: 0.1763
# Epoch: 300/1500............. Loss: 0.1776
# Epoch: 350/1500............. Loss: 0.1739
# Epoch: 400/1500............. Loss: 0.1720
# Epoch: 450/1500............. Loss: 0.1741
# Epoch: 500/1500............. Loss: 0.1729
# Epoch: 550/1500............. Loss: 0.1751
# Epoch: 600/1500............. Loss: 0.1751
# Epoch: 650/1500............. Loss: 0.1752
# Epoch: 700/1500............. Loss: 0.1750
# Epoch: 750/1500............. Loss: 0.1738
# Epoch: 800/1500............. Loss: 0.1750
# Epoch: 850/1500............. Loss: 0.1756
# Epoch: 900/1500............. Loss: 0.1736
# Epoch: 950/1500............. Loss: 0.1748
# Epoch: 1000/1500............. Loss: 0.1758
# Epoch: 1050/1500............. Loss: 0.1731
# Epoch: 1100/1500............. Loss: 0.1737
# Epoch: 1150/1500............. Loss: 0.1745
# Epoch: 1200/1500............. Loss: 0.1748
# Epoch: 1250/1500............. Loss: 0.1731
# Epoch: 1300/1500............. Loss: 0.1736
# Epoch: 1350/1500............. Loss: 0.1742
# Epoch: 1400/1500............. Loss: 0.1728
# Epoch: 1450/1500............. Loss: 0.1719
# Epoch: 1500/1500............. Loss: 0.1727
# [2020-04-15 10:42:42.324 algo-1:43 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-04-15 10:42:42,519 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-04-15 10:42:51 Uploading - Uploading generated training model
# 2020-04-15 10:42:51 Completed - Training job completed
# Training seconds: 213
# Billable seconds: 213

# %%
# %%time

# deploy your model to create a predictor
# rnn_playlist_predictor = rnn_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
